# %%
# 필요 라이브러리 임포트
import requests
from bs4 import BeautifulSoup 
import pandas as pd

# %% [markdown]
# # ably 크롤링 연습용

# %%
# 일반 url requests 확인용

# url 정의
api_url = "https://api.a-bly.com/api/v2/screens/SEARCH_RESULT/?query=%EB%8B%88%ED%8A%B8&search_type=DIRECT"

# 권한 설정
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36',
           'X-Anonymous-Token' : 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhbm9ueW1vdXNfaWQiOiIyMzkyNzcyODgiLCJpYXQiOjE3MTgyMzkwMzd9.AXFzzsBNgrqEXyT-R_x7L-20MLdNUtMJb_W5A22hXWk'
           }

# 요청
res = requests.get(api_url, headers = headers)

# 요청 상태 확인
res.status_code

# response content 확인 -> json 형태
res.text 

# json 파싱
neat_ably = res.json()

# %%
# json 구조 확인 -> title, screen_name, view_event_logging, logging, components, next_token, view_event_channels
data_key_composition = [data for data in neat_ably] 

# title -> 필요없음
# screen_name -> 필요없음
# view_event_logging -> SEARCH_RESULTS_GOODS : 검색된 총 상품 개수  
# logging -> ['logging']['analytics']['SEARCH_KEYWORD'] -> 검색어 추출하기
# componenent -> 상품'들' 정보
# next_token -> 다음 자바스크립트를 코드상에서 받기 위한 조건
# view_event_channels -> 필요없는 정보

# %%
# json 세부 정보 확인 - 3. view_event_logging -> 검색된 총 상품 개수
search_results_count = neat_ably['view_event_logging']['analytics']['SEARCH_RESULTS_GOODS']

# %%
# json 세부 정보 확인 - 4. logging -> 검색어 추출하기
search_keyword = neat_ably['logging']['analytics']['SEARCH_KEYWORD']

# %%
# json 세부 정보 확인 - 5-1 . components -> 상품 정보 제시
search_components = neat_ably['components']

# 상품 정보 구조 파악하기 -> len(components) : 12
components = [component for component in search_components]

# 컴포넌트 세부구조 파악하기 - 1단계 -> components -> 상품에 대한 세부 정보(dict) -> component_id, type(필요없어 보임), logging(아무것도 안뜨니 보류), entity(가장 중요한 정보)
good_data_key = [good_data for good_data in components[7]]

components

# component_id -> 해당 컴포넌트가 어떤 정보를 가지고 있는 지정
# 43 -> 함께 보기 좋은 기획전(광고 느낌)
# 2 -> 뭔가 쓸데없는 느낌
# 41 -> 핵심 느낌 : 상품 정보가 있는 것 같음 (ex. 인덱스 2, 10, 11 확인)

# 결론 -> component_id가 41이면 entity에 상품 정보가 있다.

# %%
good_data_key
# Out:
# ['component_id', 'type', 'logging', 'entity']

# %%
# # json 세부 정보 확인 - 5-2 . components -> 상품 정보 추출하기


# 1. components를 돌면서 component 하나씩 들어간다.
# 2. component의 id가 41인 것만 리스트에 담는다

contain_good_datas = [component for component in components if component['component_id'] == 41]


# 상품 정보 추출 과정 : component_id가 41인 것의 entity에는 상품 정보가 들어있다. -> entity -> header(안 중요해 보임), item_list(핵심 상품 정보), footer(안 중요해 보임)
id41_entity_key = [data for data in contain_good_datas[0]['entity']]


# 결론 -> component_id가 41인 것의 entity의 item_list 안에 상품 정보가 담겨져 있다.   -> goods_data
goods_data = contain_good_datas[0]['entity']['item_list']

# %%
# goods_data 구조 파악하기

# goods_data -> 상품정보 dictionary로 구성된 리스트 -> item, logging, render
good_info_key = list(set([good_key for good_data in goods_data for good_key in good_data]))
    
good_data = goods_data[0]

# %%
# 쓸만한 정보 수집(나중에 안필요해도 우선 중요해 보이면 가지고 올 것)

# good_data['item'] 세부 분석 -> 쓸만한 정보 추출 : 
good_data['item']

# key 추출하기 
item_key = [key for key in good_data['item']]

# value를 통한 key 중요도 체크✅
# name : 상품 이름✅, market_name : 쇼핑몰 이름✅, image : 대표 이미지✅, category_name : ex.니트✅ 

# 1. value 출력
for key, value in good_data['item'].items() :
    print(value)

print('___________________________________________________________________________')
print('___________________________________________________________________________')
print('___________________________________________________________________________')

item_key

# %%
# 쓸만한 정보 수집(나중에 안필요해도 우선 중요해 보이면 가지고 올 것)

# good_data['logging'] 세부 분석 -> 쓸만한 정보 추출 : 
good_data['logging']

# key 추출하기 
logging_key = [key for key in good_data['logging']]

# value를 통한 key 중요도 체크✅
# key 안의 dictionary(analytics, inhouse)
# 1. analytics ->  CATEGORY_NAME, STANDARD_CATEGORY_NAME : ex.니트(상품 카테고리)✅, SALES_PRICE : 판매 가격✅, IS_NEW : 신상품 여부✅, REVIEW_COUNT : 리뷰 수✅, LIKES_COUNT : 좋아요 수✅
# 2. inhouse ->  없음

for key, value in good_data['logging'].items() :
    print(value)

print('___________________________________________________________________________')
print('___________________________________________________________________________')
print('___________________________________________________________________________')

logging_key
# Out:
# {'GOODS_SNO': '6685702', 'GOODS_NAME': '[ 데일리/7colors! ] 페퍼 꽈배기 반팔 니트', 'MARKET_TYPE': '셀럽', 'MARKET_SNO': '2544', 'MARKET_NAME': '슬로우베리', 'CATEGORY_SNO': '299', 'CATEGORY_NAME': '니트', 'STANDARD_CATEGORY_SNO': '19', 'STANDARD_CATEGORY_NAME': '니트', 'DISCOUNT_RATE': 0, 'SALES_PRICE': 19500, 'SALES_PRICE_RANGE': '15,001~20,000', 'IS_NEW': '0', 'DELIVERY_TYPE': 'shak', 'IS_AD': '1', 'LIST_PARAMS': None, 'MARKET_TYPE_SNO': '7', 'REVIEW_COUNT': 1139, 'REVIEW_COUNT_RANGE': '1,101~1,150', 'REVIEW_RATING': 96, 'LIKES_COUNT': 17420, 'LIKES_COUNT_RANGE': '17,401~17,450', 'DELIVERY_SCORE': 97, 'PROMOTION_TAG': [], 'LIST_ID': 'search_goods_recommend', 'LIST_INDEX': 0}
# {'goods_sno': 6685702, 'list_id': 'search_goods_recommend', 'list_index': 0, 'listing': {'e': 0.0031851693, 'p': 19500, 'r': 4747, 'i': 'a2e5294f-4665-47e9-b04c-b66a2e6cbfa4'}}
# ___________________________________________________________________________
# ___________________________________________________________________________
# ___________________________________________________________________________
# ['analytics', 'inhouse']

# %%
# 쓸만한 정보 수집(나중에 안필요해도 우선 중요해 보이면 가지고 올 것)

# good_data['render'] 세부 분석 -> 쓸만한 정보 추출 : 
good_data['render']

# key 추출하기 -> 
render_key = [key for key in good_data['render']]

# value를 통한 key 중요도 체크✅
# key : size -> 사이즈 정보✅

for key, value in good_data['render'].items() :
    print(value)

print('___________________________________________________________________________')
print('___________________________________________________________________________')
print('___________________________________________________________________________')

render_key
# Out:
# MARKET
# ['PRICE', 'NAME', 'MARKET']
# MEDIUM
# {'image': {'url': 'https://d3ha2047wt6x28.cloudfront.net/A1L_Qw9bsLA/pr:NEW_GOODS_THUMB_WEBP/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzBmZTM5NGNhZjk5NDJhM2Y0NmVkOTViMDRiMDQ0YmE0LmdpZg', 'use_animation': False, 'ratio': 1.2}, 'name': '[ 데일리/7colors! ] 페퍼 꽈배기 반팔 니트', 'price': '19,500', 'has_ad_badge': False, 'name_lines': 1, 'discount_rate': None, 'closed_reason': None, 'image_badge': 'https://d3ha2047wt6x28.cloudfront.net/ws4iGPA2VJg/pr:CONVERT_TO_WEBP/czM6Ly9pbWcuYS1ibHkuY29tL2RhdGEvZ29vZHMvYmFkZ2UvYmFkZ2Vfc2hha19kZWxpdmVyeS5wbmc', 'image_badge_width': 43, 'image_badge_height': 18, 'chips': None, 'market_name': '슬로우베리', 'store_text': '슬로우베리', 'nudging_text': None, 'ranking': None, 'actions': ['LIKE'], 'discount_end_text': None, 'top_nudging_text': None, 'price_description': None}
# ___________________________________________________________________________
# ___________________________________________________________________________
# ___________________________________________________________________________
# ['type', 'contents', 'size', 'data']

# %%
# json 세부 정보 확인 - 3. next_token 
search_next_token = neat_ably['next_token']


# next_token 활용 방법
search_next_token

# next_token이 있으면 token 반환, 없으면 None 반환
neat_ably.get('next_toen')
# Out:
# None

# %%
base_url = "https://api.a-bly.com/api/v2/screens/SEARCH_RESULT/?query=%EB%8B%88%ED%8A%B8&search_type=DIRECT"


def return_json_data(url):
    # 요청 권한 설정
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36',
           'X-Anonymous-Token' : 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhbm9ueW1vdXNfaWQiOiIyMzkyNzcyODgiLCJpYXQiOjE3MTgyMzkwMzd9.AXFzzsBNgrqEXyT-R_x7L-20MLdNUtMJb_W5A22hXWk'
    }
    # 요청
    res = requests.get(url, headers = headers)
    # json 데이터, status code 반환하기
    return res.json(), res.status_code

# 1번 요청 
data, st_code = return_json_data(base_url)
# 1번 요청 -> 2번 요청으로 가기 위한 next_token 추출하기
next_token = data.get('next_token')

next_url = base_url + '&nextToken=' + next_token

next_data, next_st_code = return_json_data(next_url)

next_data, next_st_code
print(next_data)
print(next_st_code)

next2_token = next_data.get('next_token')


next_url = base_url + '&nextToken=' + next2_token

next_data, next_st_code = return_json_data(next_url)
print(next_data)
print(next_st_code)
# Out:
# {'title': '검색 결과', 'screen_name': 'SEARCH_RESULT', 'view_event_logging': {'analytics': {'SEARCH_RESULTS_GOODS': 10000, 'SEARCH_RESULTS_EVENTS': 58, 'SEARCH_RESULTS_MARKETS': 0}}, 'logging': {'analytics': {'SCREEN': 'SEARCH_RESULT', 'SEARCH_KEYWORD': '니트', 'SEARCH_TYPE': '직접입력', 'LIST_ID': 'search_goods_recommend', 'CAPSULE_NAME': None}, 'inhouse': {}}, 'components': [{'component_id': 45, 'type': {'header': None, 'item_list': 'FILTER_LIST', 'footer': None}, 'logging': {}, 'entity': {'header': None, 'item_list': [], 'footer': None, 'body': {'chip': {'refreshable': False, 'applied_query': {}, 'chip_list': [{'text': '추천순', 'logging_text': '정렬', 'is_selected': False, 'filter_token': 'eyJzY3JlZW5faWQiOiAxMSwgImZpeGVkX3F1ZXJ5IjogeyJxdWVyeSI6ICLri4jtirgiLCAiZGVsaXZlcnlfdHlwZSI6IG51bGx9LCAicGFyZW50X2dyb3VwX2lkIjogMX0='}, {'text': '카테고리', 'logging_text': '카테고리', 'is_selected': False, 'filter_token': 'eyJzY3JlZW5faWQiOiAxMSwgImZpeGVkX3F1ZXJ5IjogeyJxdWVyeSI6ICLri4jtirgiLCAiZGVsaXZlcnlfdHlwZSI6IG51bGx9LCAicGFyZW50X2dyb3VwX2lkIjogM30='}, {'text': '가격', 'logging_text': '가격', 'is_selected': False, 'filter_token': 'eyJzY3JlZW5faWQiOiAxMSwgImZpeGVkX3F1ZXJ5IjogeyJxdWVyeSI6ICLri4jtirgiLCAiZGVsaXZlcnlfdHlwZSI6IG51bGx9LCAicGFyZW50X2dyb3VwX2lkIjogNH0='}, {'text': '색상', 'logging_text': '색상', 'is_selected': False, 'filter_token': 'eyJzY3JlZW5faWQiOiAxMSwgImZpeGVkX3F1ZXJ5IjogeyJxdWVyeSI6ICLri4jtirgiLCAiZGVsaXZlcnlfdHlwZSI6IG51bGx9LCAicGFyZW50X2dyb3VwX2lkIjogNX0='}, {'text': '키·연령', 'logging_text': '키·연령', 'is_selected': False, 'filter_token': 'eyJzY3JlZW5faWQiOiAxMSwgImZpeGVkX3F1ZXJ5IjogeyJxdWVyeSI6ICLri4jtirgiLCAiZGVsaXZlcnlfdHlwZSI6IG51bGx9LCAicGFyZW50X2dyb3VwX2lkIjogNn0='}, {'text': '스타일', 'logging_text': '스타일', 'is_selected': False, 'filter_token': 'eyJzY3JlZW5faWQiOiAxMSwgImZpeGVkX3F1ZXJ5IjogeyJxdWVyeSI6ICLri4jtirgiLCAiZGVsaXZlcnlfdHlwZSI6IG51bGx9LCAicGFyZW50X2dyb3VwX2lkIjogN30='}]}}}}, {'component_id': 115, 'type': {'header': 'HEADLINE_XSMALL_ONE_LINE_TOGGLE', 'item_list': None, 'footer': None}, 'logging': {}, 'entity': {'header': {'item': {'title': "<b>상품</b> <span style='color: #777777'>9,999+</span>", 'is_on': False, 'image': 'https://img.a-bly.com/icons/icon_total_delivery.png', 'on_tint_color': '#6668FF', 'query_name': 'delivery_type', 'query_value': 'fast'}, 'logging': {'analytics': {'IS_ON': False, 'TOGGLE_TYPE': 'fast'}}}, 'item_list': [], 'footer': None}}, {'component_id': 41, 'type': {'header': None, 'item_list': 'THREE_COL_GOODS_LIST', 'footer': None}, 'logging': {'analytics': {'LIST_ID': 'search_goods_recommend'}, 'inhouse': {'list_id': 'search_goods_recommend', 'list_params': '{"order": "recommend", "search_keyword": "니트"}'}}, 'entity': {'header': None, 'item_list': [{'item': {'sno': 6685702, 'name': '[ 데일리/7colors! ] 페퍼 꽈배기 반팔 니트', 'market_sno': 2544, 'market_name': '슬로우베리', 'image': 'https://d3ha2047wt6x28.cloudfront.net/tPdCa8xRBEo/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzBmZTM5NGNhZjk5NDJhM2Y0NmVkOTViMDRiMDQ0YmE0LmdpZg', 'closed_reason': None, 'sell_count': 8351, 'delivery_type': 'shak', 'ranking': None, 'available_only_new_member': False, 'first_page_rendering': None, 'is_premium_hotdeal': False, 'is_hotdeal': False, 'is_new': False, 'price': 19500, 'discount_rate': 0, 'like': {'goods_sno': 6685702, 'is_liked': False, 'folder_sno': None, 'referrer': {'list_id': 'search_goods_recommend', 'list_index': 0}}, 'ad': {'list_id': 'search_recommend', 'campaign_id': '282366', 'parameters': '{"generated_at": "2024-06-18 14:07:53", "market_sno": 2544, "ad_market_sno": 9, "search_keyword": "\\ub2c8\\ud2b8", "ei": "", "list_index": 0}', 'goods_sno': 6685702}, 'on_return': {'type': 'INJECT', 'data': {'url': 'goods/6685702/recommend_related_goods_by_click/?from=S ...
# 200
# {'title': '검색 결과', 'screen_name': 'SEARCH_RESULT', 'view_event_logging': {'analytics': {'SEARCH_RESULTS_GOODS': 10000, 'SEARCH_RESULTS_EVENTS': 58, 'SEARCH_RESULTS_MARKETS': 0}}, 'logging': {'analytics': {'SCREEN': 'SEARCH_RESULT', 'SEARCH_KEYWORD': '니트', 'SEARCH_TYPE': '직접입력', 'LIST_ID': 'search_goods_recommend', 'CAPSULE_NAME': None}, 'inhouse': {}}, 'components': [{'component_id': 45, 'type': {'header': None, 'item_list': 'FILTER_LIST', 'footer': None}, 'logging': {}, 'entity': {'header': None, 'item_list': [], 'footer': None, 'body': {'chip': {'refreshable': False, 'applied_query': {}, 'chip_list': [{'text': '추천순', 'logging_text': '정렬', 'is_selected': False, 'filter_token': 'eyJzY3JlZW5faWQiOiAxMSwgImZpeGVkX3F1ZXJ5IjogeyJxdWVyeSI6ICLri4jtirgiLCAiZGVsaXZlcnlfdHlwZSI6IG51bGx9LCAicGFyZW50X2dyb3VwX2lkIjogMX0='}, {'text': '카테고리', 'logging_text': '카테고리', 'is_selected': False, 'filter_token': 'eyJzY3JlZW5faWQiOiAxMSwgImZpeGVkX3F1ZXJ5IjogeyJxdWVyeSI6ICLri4jtirgiLCAiZGVsaXZlcnlfdHlwZSI6IG51bGx9LCAicGFyZW50X2dyb3VwX2lkIjogM30='}, {'text': '가격', 'logging_text': '가격', 'is_selected': False, 'filter_token': 'eyJzY3JlZW5faWQiOiAxMSwgImZpeGVkX3F1ZXJ5IjogeyJxdWVyeSI6ICLri4jtirgiLCAiZGVsaXZlcnlfdHlwZSI6IG51bGx9LCAicGFyZW50X2dyb3VwX2lkIjogNH0='}, {'text': '색상', 'logging_text': '색상', 'is_selected': False, 'filter_token': 'eyJzY3JlZW5faWQiOiAxMSwgImZpeGVkX3F1ZXJ5IjogeyJxdWVyeSI6ICLri4jtirgiLCAiZGVsaXZlcnlfdHlwZSI6IG51bGx9LCAicGFyZW50X2dyb3VwX2lkIjogNX0='}, {'text': '키·연령', 'logging_text': '키·연령', 'is_selected': False, 'filter_token': 'eyJzY3JlZW5faWQiOiAxMSwgImZpeGVkX3F1ZXJ5IjogeyJxdWVyeSI6ICLri4jtirgiLCAiZGVsaXZlcnlfdHlwZSI6IG51bGx9LCAicGFyZW50X2dyb3VwX2lkIjogNn0='}, {'text': '스타일', 'logging_text': '스타일', 'is_selected': False, 'filter_token': 'eyJzY3JlZW5faWQiOiAxMSwgImZpeGVkX3F1ZXJ5IjogeyJxdWVyeSI6ICLri4jtirgiLCAiZGVsaXZlcnlfdHlwZSI6IG51bGx9LCAicGFyZW50X2dyb3VwX2lkIjogN30='}]}}}}, {'component_id': 115, 'type': {'header': 'HEADLINE_XSMALL_ONE_LINE_TOGGLE', 'item_list': None, 'footer': None}, 'logging': {}, 'entity': {'header': {'item': {'title': "<b>상품</b> <span style='color: #777777'>9,999+</span>", 'is_on': False, 'image': 'https://img.a-bly.com/icons/icon_total_delivery.png', 'on_tint_color': '#6668FF', 'query_name': 'delivery_type', 'query_value': 'fast'}, 'logging': {'analytics': {'IS_ON': False, 'TOGGLE_TYPE': 'fast'}}}, 'item_list': [], 'footer': None}}, {'component_id': 41, 'type': {'header': None, 'item_list': 'THREE_COL_GOODS_LIST', 'footer': None}, 'logging': {'analytics': {'LIST_ID': 'search_goods_recommend'}, 'inhouse': {'list_id': 'search_goods_recommend', 'list_params': '{"order": "recommend", "search_keyword": "니트"}'}}, 'entity': {'header': None, 'item_list': [{'item': {'sno': 6685702, 'name': '[ 데일리/7colors! ] 페퍼 꽈배기 반팔 니트', 'market_sno': 2544, 'market_name': '슬로우베리', 'image': 'https://d3ha2047wt6x28.cloudfront.net/tPdCa8xRBEo/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzBmZTM5NGNhZjk5NDJhM2Y0NmVkOTViMDRiMDQ0YmE0LmdpZg', 'closed_reason': None, 'sell_count': 8351, 'delivery_type': 'shak', 'ranking': None, 'available_only_new_member': False, 'first_page_rendering': None, 'is_premium_hotdeal': False, 'is_hotdeal': False, 'is_new': False, 'price': 19500, 'discount_rate': 0, 'like': {'goods_sno': 6685702, 'is_liked': False, 'folder_sno': None, 'referrer': {'list_id': 'search_goods_recommend', 'list_index': 0}}, 'ad': {'list_id': 'search_recommend', 'campaign_id': '282366', 'parameters': '{"generated_at": "2024-06-18 14:07:54", "market_sno": 2544, "ad_market_sno": 9, "search_keyword": "\\ub2c8\\ud2b8", "ei": "", "list_index": 0}', 'goods_sno': 6685702}, 'on_return': {'type': 'INJECT', 'data': {'url': 'goods/6685702/recommend_related_goods_by_click/?from=S ...
# 200

# %%
# chat-gpt 활용방안
import requests

base_url = 'https://example.com'

def fetch_data(url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    response = requests.get(url, headers=headers)
    return response.json()

# 첫 번째 요청
data = fetch_data(base_url)
items = data['items']
next_token = data.get('nextToken')

# 다음 페이지 요청 반복
while next_token:
    next_url = f'{base_url}&nextToken={next_token}'
    data = fetch_data(next_url)
    items.extend(data['items'])
    next_token = data.get('nextToken')

# 모든 데이터 처리 완료
print(items)

# %%
# json 세부 정보 확인 - 3. view_event_channels -> 필요없는 정보 같음
search_event_channels = neat_ably['view_event_channels']


# next_token 활용 방법
search_event_channels
# Out:
# ['firebase', 'amplitude', 'braze']

# %% [markdown]
# # ably 크롤링 코드 일반화시키기
#
# 1. javascript로 들어오는 api_url을 받는다.
#
# 2. res.json()을 반환받는다. ably = res.json()
#
# 3. 총 상품 개수 추출(삭제 -> 안함)
# res.json()['view_event_logging']['analytics']['SEARCH_RESULTS_GOODS']
#
# 4. 검색어 추출하기
# res.json()['logging']['analytics']['SEARCH_KEYWORD']
#
# 5. 상품 정보 가지고 오기
#     1. res.json()['components'] -> 이 안에는 여러 component가 리스트안에 들어가 있다
#     2. res.json()['components']을 반복문 돈다. -> 하나의 컴포넌트에 접근한다.
#     3. 하나의 컴포넌트에 접근하면서 component_id가 41인 것의 entity를 가지고 온다. -> 리스트 형태로 저장한다 -> filtered_components
#     4. filtered_components를 반복문을 돌면서 하나의 entity에 접근한다.
#     5. 해당 entity의  item_list에 접근한다 -> 핵심적인 상품 정보'들'이 존재한다. -> goods_data
#     6. goods_data를 반복문 돈다. -> 하나의 상품 good_data에 접근한다. -> item, logging, render 존재
#     7. good_data['item']  -> name, market_name, image, category_name
#     8. good_data['logging'] -> analytics
#         -> CATEGORY_NAME, STANDARD_CATEGORY_NAME, SALES_PRICE, IS_NEW, REVIEW_COUNT, LIKES_COUNT
#     9. good_data['render'] -> size 가지고오기
# 6. res.json()['next_token'] -> next_token을 받아서 다음 api_url에 대해 위의 과정을 반복한다.

# %%
# 1. javascript로 들어오는 api_url을 받는다.
api_url = 'https://api.a-bly.com/api/v2/screens/SEARCH_RESULT/?query=%EB%8B%88%ED%8A%B8&search_type=DIRECT' # 니트
# 'https://api.a-bly.com/api/v2/screens/SEARCH_RESULT/?query=%EB%8B%88%ED%8A%B8&search_type=DIRECT'

# 2. res.json()을 반환받는다.
def return_json_data(url) :
    # 권한 설정
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36',
            'X-Anonymous-Token' : 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhbm9ueW1vdXNfaWQiOiIyMzkyNzcyODgiLCJpYXQiOjE3MTgyMzkwMzd9.AXFzzsBNgrqEXyT-R_x7L-20MLdNUtMJb_W5A22hXWk'
            }
    # 요청
    res = requests.get(url, headers = headers)
    # 요청 상태 확인
    res.status_code
    # json 파싱
    return res.json(), res.status_code

ably, st_code = return_json_data(api_url) 

# 3. 총 상품 개수 추출 -> 안함.
# 4. 검색어 추출하기
search_keyword = ably['logging']['analytics']['SEARCH_KEYWORD']
print(f'검색어 : {search_keyword}')

# 5. 상품 정보 가지고 오기
filtered_components = [component['entity'] for component in ably['components'] if component['component_id'] == 41]

for entity in filtered_components :
    goods_data = entity['item_list']
    for good_data in goods_data :
        print(f"제품명 : {good_data['item']['name']}")
        print(f"브랜드 : {good_data['item']['market_name']}")
        print(f"이미지 url : {good_data['item']['image']}")
        print(f"카테고리 : {good_data['item']['category_name']}")
        
        # print(f"카테고리-2 : {good_data['logging']['analytics']['CATEGORY_NAME']}")
        # print(f"카테고리-3 : {good_data['logging']['analytics']['STANDARD_CATEGORY_NAME']}")
        print(f"판매가 : {good_data['logging']['analytics']['SALES_PRICE']}")
        print(f"신상품 여부 : {good_data['logging']['analytics']['IS_NEW']}")
        print(f"리뷰 수 : {good_data['logging']['analytics']['REVIEW_COUNT']}")
        print(f"좋아요 수 : {good_data['logging']['analytics']['LIKES_COUNT']}")

        print(f"제품 사이즈 : { 'FREE' if good_data['render']['size'] == 'MEDIUM' else good_data['render']['size'] }")

# 6. res.json()['next_token'] -> next_token을 받아서 다음 api_url에 대해 위의 과정을 반복한다.
next_token = ably['next_token']
next_url = f'{api_url}&nextToken={next_token}'


ably, st_code = return_json_data(next_url) 

# 3. 총 상품 개수 추출 -> 안함.
# 4. 검색어 추출하기
search_keyword = ably['logging']['analytics']['SEARCH_KEYWORD']
print(f'검색어 : {search_keyword}')

# 5. 상품 정보 가지고 오기
filtered_components = [component['entity'] for component in ably['components'] if component['component_id'] == 41]

for entity in filtered_components :
    goods_data = entity['item_list']
    for good_data in goods_data :
        print(f"제품명 : {good_data['item']['name']}")
        print(f"브랜드 : {good_data['item']['market_name']}")
        print(f"이미지 url : {good_data['item']['image']}")
        print(f"카테고리 : {good_data['item']['category_name']}")
        
        # print(f"카테고리-2 : {good_data['logging']['analytics']['CATEGORY_NAME']}")
        # print(f"카테고리-3 : {good_data['logging']['analytics']['STANDARD_CATEGORY_NAME']}")
        print(f"판매가 : {good_data['logging']['analytics']['SALES_PRICE']}")
        print(f"신상품 여부 : {good_data['logging']['analytics']['IS_NEW']}")
        print(f"리뷰 수 : {good_data['logging']['analytics']['REVIEW_COUNT']}")
        print(f"좋아요 수 : {good_data['logging']['analytics']['LIKES_COUNT']}")

        print(f"제품 사이즈 : { 'FREE' if good_data['render']['size'] == 'MEDIUM' else good_data['render']['size'] }")
# Out:
# 검색어 : 니트
# 제품명 : [ 데일리/7colors! ] 페퍼 꽈배기 반팔 니트
# 브랜드 : 슬로우베리
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/tPdCa8xRBEo/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzBmZTM5NGNhZjk5NDJhM2Y0NmVkOTViMDRiMDQ0YmE0LmdpZg
# 카테고리 : 니트
# 판매가 : 19500
# 신상품 여부 : 0
# 리뷰 수 : 1139
# 좋아요 수 : 17430
# 제품 사이즈 : FREE
# 제품명 : [ 부드러워요!/캐시소재 ] 멜로우 v넥 반팔 니트
# 브랜드 : 슬로우베리
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/PoA7knbIbcc/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzL2ZlNDI3NjdlMTc3NjczNmNlNTZhMjA2MzIwOWFkNjUzLmdpZg
# 카테고리 : 니트
# 판매가 : 16500
# 신상품 여부 : 0
# 리뷰 수 : 350
# 좋아요 수 : 4786
# 제품 사이즈 : FREE
# 제품명 : [데일리/9colors] 프루츠 라운드 반팔 니트
# 브랜드 : 슬로우베리
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/2ZPyssm2nxE/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzIwMjIwNjIzXzE2NTU5NTgwMTk5MzY2NDhzLmdpZg
# 카테고리 : 니트
# 판매가 : 17500
# 신상품 여부 : 0
# 리뷰 수 : 229
# 좋아요 수 : 3987
# 제품 사이즈 : FREE
# 제품명 : 당일발송｜[가벼워요/여름가디건] 웨이 린넨니트 크롭 기본 가디건 - 12color
# 브랜드 : 슈가파우더
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/4k7hTtQXgDM/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzRjN2MwNTFiMTM0NTZkOTE3MjNjOTU1MThlMDg1ZjRmLmdpZg
# 카테고리 : 가디건
# 판매가 : 19990
# 신상품 여부 : 0
# 리뷰 수 : 1572
# 좋아요 수 : 54883
# 제품 사이즈 : FREE
# 제품명 : [뱀부소재]스퀘어넥 소매퍼프 반팔니트-5color
# 브랜드 : 인더모어
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/huMkBkk5Tn0/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzIwMjEwNTE3XzE2MjEyMzM5MTI4MjA2MjdzLmdpZg
# 카테고리 : 니트
# 판매가 : 19900
# 신상품 여부 : 0
# 리뷰 수 : 1254
# 좋아요 수 : 18889
# 제품 사이즈 : FREE
# 제품명 : 반팔니트✨#제작 [tnt0615] 라티스 배색 라운드 케이블 니트(배색니트,포인트니트,반팔니트,여름니트,케이블니트,라운드니트)
# 브랜드 : 어나더트위
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/5Z7n5Om8cOs/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzL2MyNjM3YTM5NGE1MjQ2NDQ0ODA5YzIyMjJhODUxOWQ1LmdpZg
# 카테고리 : 니트
# 판매가 : 22320
# 신상품 여부 : 0
# 리뷰 수 : 3
# 좋아요 수 : 488
# 제품 사이즈 : FREE
# 제품명 : [최저가/여름까지] 펀칭 스트링 레이어드 그물니트
# 브랜드 : 모던어스
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/SyynbSS5pSk/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzg3YjY1ZmUwMDVkNmNkMWQ4ZmE1MmJiMmNhZmQyODE0LmdpZg
# 카테고리 : 니트
# 판매가 : 15500
# 신상품 여부 : 0
# 리뷰 수 : 70
# 좋아요 수 : 5114
# 제품 사이즈 : FREE
# 제품명 : 2500장판매돌파⭐️몬트 여리여리 망사 메쉬 니트 4color
# 브랜드 : 오프업
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/sm1Y2oVdnCI/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzL2IyZmVkNTk2NWNmMzZjNDNiMzJkZTRiOTQ2ODE4OTg4LmpwZw
# 카테고리 : 니트
# 판매가 : 29700
# 신상품 여부 : 0
# 리뷰 수 : 222
# 좋아요 수 : 12176
# 제품 사이즈 : FREE
# 제품명 : 당일발송｜[고급여름원단/데일리] 시원한, 뱀부 반팔 니트가디건 - 7color
# 브랜드 : 슈가파우더
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/0_IBECbTB34/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzg1M2QwOTgzZjc2MGNlMDMzOWIxNjY1YTQ3YmUxZjQ3LmdpZg
# 카테고리 : 가디건
# 판매가 : 19850
# 신상품 여부 : 0
# 리뷰 수 : 2
# 좋아요 수 : 879
# 제품 사이즈 : FREE
# 제품명 : [자체제작/~4XL] 썸머무드 브이넥 팔뚝반팔 단추 골지 아이스 니트 빅사이즈 오버핏시스루니트 슬림핏반팔티 링클반팔 린넨 여름니트
# 브랜드 : 오야드(OYD)
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/qVWmAXfoOmw/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzA2Y2JkYzczMjhjZjQ0ZTA0N2FiZjE0NzUwZDU5YTI1LmdpZg
# 카테고리 : 니트
# 판매가 : 18300
# 신상품 여부 : 0
# 리뷰 수 : 161
# 좋아요 수 : 2361
# 제품 사이즈 : FREE
# 제품명 : [원조핏*.*❤/후기보장!] 리본 어깨트임 시스루 루즈핏 부클 긴팔니트 - 5color
# 브랜드 : 슈가파우더
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/lAZ6mTopYBM/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzA2YjkzNmZkOGMwZjMxNzg4ZDE5YmUxNzExYjYxMzYxLmdpZg
# 카테고리 : 니트
# 판매가 : 14630
# 신상품 여부 : 0
# 리뷰 수 : 648
# 좋아요 수 : 22496
# 제품 사이즈 : FREE
# 제품명 : [💌도씨입문템 6%/후기인증니트][98project/1만장돌파] 톡톡 와플 반팔 니트 - 7 color ("민트그린,스카이블루" 프리오더)
# 브랜드 : 98도씨
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/GL3oIH0Ju2k/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzUwNjAxNzI0NTZmNWFlNTRmMzcwMTM3M2MwMDVlYTY3LmdpZg
# 카테고리 : 니트
# 판매가 : 32000
# 신상품 여부 : 0
# 리뷰 수 : 670
# 좋아요 수 : 22933
# 제품 사이즈 : FREE
# 제품명 : [한여름까지!여리여리] 살탐방지 빅사이즈 시스루 오버핏 브이넥 부클 스트릿 박시핏 니트
# 브랜드 : 블리즈
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/dkVDNCirrlk/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzL2I1MGY5MDNmMThhMzZkYzE1YjY2ZGY1ZTg2ZTg1NjE1LmdpZg
# 카테고리 : 니트
# 판매가 : 15500
# 신상품 여부 : 0
# 리뷰 수 : 8
# 좋아요 수 : 1290
# 제품 사이즈 : FREE
# 제품명 : [44-120] [2천장 돌파✨] 크리딘 스판 오픈카라 배색 니트
# 브랜드 : 리리앤코
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/Qu6BaJI2gRc/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzL2VhODllMjFhM2YzYjZkMmQ3YjJiNjg5Zjc2ZWE3Y2RmLmpwZw
# 카테고리 : 니트
# 판매가 : 26010
# 신상품 여부 : 0
# 리뷰 수 : 106
# 좋아요 수 : 4019
# 제품 사이즈 : FREE
# 제품명 : [썸머니트/루즈핏]슈링그물펀칭박스핏니트(4color)
# 브랜드 : 꼬맹
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/X6OLNFGtE8s/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzQzMzViMDFkNDI5YzliNTgwZThkNGZiYjQwZWUxOWU4LmdpZg
# 카테고리 : 니트
# 판매가 : 13900
# 신상품 여부 : 0
# 리뷰 수 : 3
# 좋아요 수 : 1552
# 제품 사이즈 : FREE
# 제품명 : [3500장 돌파/여름니트] unique hole knit (3color)
# 브랜드 : 바이마이미
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/JMBq7xa39qY/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzL2I5ZjA5MDNkNjQ0MjAzNDBhNGIyZTc3YmFkOGM5NGZhLmdpZg
# 카테고리 : 니트
# 판매가 : 18410
# 신상품 여부 : 0
# 리뷰 수 : 383
# 좋아요 수 : 19250
# 제품 사이즈 : FREE
# 제품명 : [🔥1+1추가할인🔥/갓성비] 최저가 재 진행! 여름 썸머 니트!~
# 브랜드 : 조이몰
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/W1jfYbLRK04/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzhiYmQ1OTI5ZjliOGMyNzI3ZDVkNmM5ODNmYTM5MzliLmdpZg
# 카테고리 : 니트
# 판매가 : 13800
# 신상품 여부 : 0
# 리뷰 수 : 6
# 좋아요 수 : 1234
# 제품 사이즈 : FREE
# 제품명 : [🏆니트1위/누적판매5만장] 오프닝 배색 니트 /여름니트/휴양지룩/바캉스/여름반팔니트/팔뚝살커버/여름하객룩
# 브랜드 : 체리코코
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/bVI5ELTGCdM/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzYzYTk1OGYzYWE1NDQ5YTYxZmNiZDBkMGRmYzVlYTJkLmdpZg
# 카테고리 : 니트
# 판매가 : 19900
# 신상품 여부 : 0
# 리뷰 수 : 396
# 좋아요 수 : 4433
# 제품 사이즈 : FREE
# 제품명 : [Mayvi/여름니트] ditu 린넨 반팔 니트 (3 color)
# 브랜드 : 언더비
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/tTEx3wQttf8/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzL2I0MjY2Y2NhNDk2NzM3N2EzZTBkZWFjNTdjNjYyZjY4LmdpZg
# 카테고리 : 니트
# 판매가 : 29450
# 신상품 여부 : 0
# 리뷰 수 : 16
# 좋아요 수 : 2512
# 제품 사이즈 : FREE
# 제품명 : [MADE/당일발송🎁] 샐러리 카라 반팔 니트 - 4color
# 브랜드 : 멜로우어썸
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/xlJbkFweFEg/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzExMWYyOWRjNmI1YmE3MjA2NDA4Mzk4NWIzZGE5NDhlLmdpZg
# 카테고리 : 니트
# 판매가 : 36540
# 신상품 여부 : 0
# 리뷰 수 : 72
# 좋아요 수 : 4968
# 제품 사이즈 : FREE
# 제품명 : [살안타템!/여리여리~] 손등덮는 루즈핏 부클 린넨 크롭 브이넥 긴팔 니트 (7color)
# 브랜드 : 베리버블
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/_KJ9iFt0qUs/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzZmMGQxODMzYjlhYmJhMmE1NTVkMWFkZTc0Njk1MDIxLmdpZg
# 카테고리 : 니트
# 판매가 : 15500
# 신상품 여부 : 0
# 리뷰 수 : 259
# 좋아요 수 : 10298
# 제품 사이즈 : FREE
# 제품명 : [15천장돌파][무려9컬러!] 둥글 스퀘어넥 반팔 니트 (9color)
# 브랜드 : 프리티띵즈
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/G2LxLgjnU0E/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzNjZTIxNTlkYjgzOGMwOTdhZmZhODgzYjMxMDAwZTA2LmdpZg
# 카테고리 : 니트
# 판매가 : 20500
# 신상품 여부 : 0
# 리뷰 수 : 3052
# 좋아요 수 : 41863
# 제품 사이즈 : FREE
# 제품명 : [오늘출발][3천장돌파/린넨니트/바캉스룩][자체제작] mnt607 쿨링 여리핏 유넥 린넨 니트
# 브랜드 : 에드모어
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/KwSbsUPWf30/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzL2JhZDJkN2E4MmI5YmMyYmEyYTRiZjY3ZTJlZWM5NGRmLmdpZg
# 카테고리 : 니트
# 판매가 : 31500
# 신상품 여부 : 0
# 리뷰 수 : 43
# 좋아요 수 : 1411
# 제품 사이즈 : FREE
# 제품명 : 배색자수니트-knit (아무거나 말고 예쁜룩😍)
# 브랜드 : 디스코살롱
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/5TIytMl4xQ0/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzYwYjJkNTg4OTcxYjY0ZjgyYzIyNDU2MjQ4NGRhNmEwLmdpZg
# 카테고리 : 니트
# 판매가 : 20000
# 신상품 여부 : 0
# 리뷰 수 : 42
# 좋아요 수 : 545
# 제품 사이즈 : FREE
# 제품명 : 당일발송｜[조절ok!/반팔ver.🤍] 오브 뱀부 트임 반팔 랩니트 티셔츠 - 5color
# 브랜드 : 슈가파우더
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/2kpPP0J11-0/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzL2QwN2FkOGVhN2FhNWVjYjZkMjRjNTE5ZTZiYjViZDQyLmdpZg
# 카테고리 : 니트
# 판매가 : 22700
# 신상품 여부 : 0
# 리뷰 수 : 108
# 좋아요 수 : 6577
# 제품 사이즈 : FREE
# 제품명 : [주문폭주/예쁨주의] 인기 재진행 색상추가💕썸머 부클 반팔 니트 - nt
# 브랜드 : 우원
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/3woGbux7hMU/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzIwMjIwNTEyXzE2NTIzNjA1NDgwNjEzOTBzLmdpZg
# 카테고리 : 니트
# 판매가 : 16450
# 신상품 여부 : 0
# 리뷰 수 : 410
# 좋아요 수 : 9844
# 제품 사이즈 : FREE
# 제품명 : 반팔ver.[일체형!/데일리힙]셔츠꽈배기니트레이어드반팔(5color)
# 브랜드 : 꼬맹
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/UNIcNe4hSMg/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzE4Y2M1ZjJiZDJmZjRjOTEzMjQwOTZhYmZlNGRlYjI1LmdpZg
# 카테고리 : 니트
# 판매가 : 14900
# 신상품 여부 : 0
# 리뷰 수 : 357
# 좋아요 수 : 17244
# 제품 사이즈 : FREE
# 제품명 : [44-120] [1만장 돌파♥] 르마턴 꽈배기 세미크롭 브이넥 반팔 니트
# 브랜드 : 리리앤코
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/-o6K32oNrRg/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzL2ZjNmQzNzAxNDllYTRlNDkzZmY5ZjRkNDU3ZTQzYjE4LmpwZw
# 카테고리 : 니트
# 판매가 : 24210
# 신상품 여부 : 0
# 리뷰 수 : 569
# 좋아요 수 : 10785
# 제품 사이즈 : FREE
# 제품명 : [🎁재진행] 골지 브이넥 카라 반팔 니트 - 6 color
# 브랜드 : 메이글
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/fmg4oRg88pw/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzL2IzZThmNTNjZjViNjNmZjNlNTNkMDMxZDI1NTgzNGYyLmdpZg
# 카테고리 : 니트
# 판매가 : 16240
# 신상품 여부 : 0
# 리뷰 수 : 7
# 좋아요 수 : 152
# 제품 사이즈 : FREE
# 제품명 : 🚚당일출고🚚[가벼운니트재질] 골지 카라넥 반팔 가디건
# 브랜드 : 리리의감각
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/5zLq7og9sb8/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzUyZTdjOTgyYTFkMTUxMzFkN2M1MmVjODM3NmU0YzBkLmdpZg
# 카테고리 : 가디건
# 판매가 : 14900
# 신상품 여부 : 0
# 리뷰 수 : 1811
# 좋아요 수 : 26476
# 제품 사이즈 : FREE
# 제품명 : [허리버튼!/색감맛집] 데일리, 부드러운 유넥 크롭 반팔니트 (9color)
# 브랜드 : 앤드모어
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/Fg2kSH5D1KM/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzg0MzJmZDdhNmIyNjY3NzNjYTM5NDRiZDU0MTRlOTlmLmdpZg
# 카테고리 : 니트
# 판매가 : 19500
# 신상품 여부 : 0
# 리뷰 수 : 183
# 좋아요 수 : 5804
# 제품 사이즈 : FREE
# 제품명 : [44-120] [1만4천장 돌파♥] 데니샤 스판 울 니트 세미크롭 오픈카라 브이넥 가디건
# 브랜드 : 리리앤코
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/VqMWhJSwyIw/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzL2YyYjA5ZWZmYWEzOTkxZDdhNjQ0YmRjOTUwN2E5NmE5LmpwZw
# 카테고리 : 니트
# 판매가 : 25110
# 신상품 여부 : 0
# 리뷰 수 : 543
# 좋아요 수 : 7758
# 제품 사이즈 : FREE
# 제품명 : *[기본템] FW 올리 브이넥 루즈핏 니트 티셔츠 6color [BKK-0393]
# 브랜드 : 모노치코
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/z1ytGtYr2kI/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzL2U3NjExY2U0Y2U3YzI1MWIzOGNlMDFmNmExZTZlYjlhLmpwZw
# 카테고리 : 니트
# 판매가 : 15800
# 신상품 여부 : 0
# 리뷰 수 : 142
# 좋아요 수 : 1848
# 제품 사이즈 : FREE
# 제품명 : [44~100] 극여리핏 린넨 썸머 루즈핏 가디건
# 브랜드 : 쏠트베이비
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/P4ACozxJuBA/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzMwNmU2ZGY0YTFhOGY4NmY5MWRlZDlkNzVjNDcwYjJkLmdpZg
# 카테고리 : 가디건
# 판매가 : 17500
# 신상품 여부 : 0
# 리뷰 수 : 727
# 좋아요 수 : 10448
# 제품 사이즈 : FREE
# 제품명 : 오션 케이블 루즈 썸머 보트넥 니트 (5color)
# 브랜드 : 쇼퍼랜드
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/8P9gZVZZoh8/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzAxNjFkZjI4MjQyMDZjMWRkNjJjMGE3NDA0MzYwYmQ2LmdpZg
# 카테고리 : 니트
# 판매가 : 16650
# 신상품 여부 : 0
# 리뷰 수 : 106
# 좋아요 수 : 4194
# 제품 사이즈 : FREE
# 제품명 : [데일리] 모던 카라 꽈배기 반팔 니트
# 브랜드 : 슬로우베리
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/38K7zRWIMGA/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzIwMjIwNzEyXzE2NTc2MTgxNTE5MjI2ODJzLmdpZg
# 카테고리 : 니트
# 판매가 : 25500
# 신상품 여부 : 0
# 리뷰 수 : 2
# 좋아요 수 : 92
# 제품 사이즈 : FREE
# 검색어 : 니트
# 제품명 : [ 데일리/7colors! ] 페퍼 꽈배기 반팔 니트
# 브랜드 : 슬로우베리
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/tPdCa8xRBEo/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzBmZTM5NGNhZjk5NDJhM2Y0NmVkOTViMDRiMDQ0YmE0LmdpZg
# 카테고리 : 니트
# 판매가 : 19500
# 신상품 여부 : 0
# 리뷰 수 : 1139
# 좋아요 수 : 17430
# 제품 사이즈 : FREE
# 제품명 : [ 부드러워요!/캐시소재 ] 멜로우 v넥 반팔 니트
# 브랜드 : 슬로우베리
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/PoA7knbIbcc/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzL2ZlNDI3NjdlMTc3NjczNmNlNTZhMjA2MzIwOWFkNjUzLmdpZg
# 카테고리 : 니트
# 판매가 : 16500
# 신상품 여부 : 0
# 리뷰 수 : 350
# 좋아요 수 : 4786
# 제품 사이즈 : FREE
# 제품명 : [데일리/9colors] 프루츠 라운드 반팔 니트
# 브랜드 : 슬로우베리
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/2ZPyssm2nxE/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzIwMjIwNjIzXzE2NTU5NTgwMTk5MzY2NDhzLmdpZg
# 카테고리 : 니트
# 판매가 : 17500
# 신상품 여부 : 0
# 리뷰 수 : 229
# 좋아요 수 : 3987
# 제품 사이즈 : FREE
# 제품명 : 당일발송｜[가벼워요/여름가디건] 웨이 린넨니트 크롭 기본 가디건 - 12color
# 브랜드 : 슈가파우더
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/4k7hTtQXgDM/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzRjN2MwNTFiMTM0NTZkOTE3MjNjOTU1MThlMDg1ZjRmLmdpZg
# 카테고리 : 가디건
# 판매가 : 19990
# 신상품 여부 : 0
# 리뷰 수 : 1572
# 좋아요 수 : 54883
# 제품 사이즈 : FREE
# 제품명 : [뱀부소재]스퀘어넥 소매퍼프 반팔니트-5color
# 브랜드 : 인더모어
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/huMkBkk5Tn0/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzIwMjEwNTE3XzE2MjEyMzM5MTI4MjA2MjdzLmdpZg
# 카테고리 : 니트
# 판매가 : 19900
# 신상품 여부 : 0
# 리뷰 수 : 1254
# 좋아요 수 : 18889
# 제품 사이즈 : FREE
# 제품명 : 반팔니트✨#제작 [tnt0615] 라티스 배색 라운드 케이블 니트(배색니트,포인트니트,반팔니트,여름니트,케이블니트,라운드니트)
# 브랜드 : 어나더트위
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/5Z7n5Om8cOs/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzL2MyNjM3YTM5NGE1MjQ2NDQ0ODA5YzIyMjJhODUxOWQ1LmdpZg
# 카테고리 : 니트
# 판매가 : 22320
# 신상품 여부 : 0
# 리뷰 수 : 3
# 좋아요 수 : 488
# 제품 사이즈 : FREE
# 제품명 : [최저가/여름까지] 펀칭 스트링 레이어드 그물니트
# 브랜드 : 모던어스
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/SyynbSS5pSk/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzg3YjY1ZmUwMDVkNmNkMWQ4ZmE1MmJiMmNhZmQyODE0LmdpZg
# 카테고리 : 니트
# 판매가 : 15500
# 신상품 여부 : 0
# 리뷰 수 : 70
# 좋아요 수 : 5114
# 제품 사이즈 : FREE
# 제품명 : 2500장판매돌파⭐️몬트 여리여리 망사 메쉬 니트 4color
# 브랜드 : 오프업
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/sm1Y2oVdnCI/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzL2IyZmVkNTk2NWNmMzZjNDNiMzJkZTRiOTQ2ODE4OTg4LmpwZw
# 카테고리 : 니트
# 판매가 : 29700
# 신상품 여부 : 0
# 리뷰 수 : 222
# 좋아요 수 : 12177
# 제품 사이즈 : FREE
# 제품명 : 당일발송｜[고급여름원단/데일리] 시원한, 뱀부 반팔 니트가디건 - 7color
# 브랜드 : 슈가파우더
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/0_IBECbTB34/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzg1M2QwOTgzZjc2MGNlMDMzOWIxNjY1YTQ3YmUxZjQ3LmdpZg
# 카테고리 : 가디건
# 판매가 : 19850
# 신상품 여부 : 0
# 리뷰 수 : 2
# 좋아요 수 : 879
# 제품 사이즈 : FREE
# 제품명 : [원조핏*.*❤/후기보장!] 리본 어깨트임 시스루 루즈핏 부클 긴팔니트 - 5color
# 브랜드 : 슈가파우더
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/lAZ6mTopYBM/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzA2YjkzNmZkOGMwZjMxNzg4ZDE5YmUxNzExYjYxMzYxLmdpZg
# 카테고리 : 니트
# 판매가 : 14630
# 신상품 여부 : 0
# 리뷰 수 : 648
# 좋아요 수 : 22496
# 제품 사이즈 : FREE
# 제품명 : [자체제작/~4XL] 썸머무드 브이넥 팔뚝반팔 단추 골지 아이스 니트 빅사이즈 오버핏시스루니트 슬림핏반팔티 링클반팔 린넨 여름니트
# 브랜드 : 오야드(OYD)
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/qVWmAXfoOmw/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzA2Y2JkYzczMjhjZjQ0ZTA0N2FiZjE0NzUwZDU5YTI1LmdpZg
# 카테고리 : 니트
# 판매가 : 18300
# 신상품 여부 : 0
# 리뷰 수 : 161
# 좋아요 수 : 2361
# 제품 사이즈 : FREE
# 제품명 : [💌도씨입문템 6%/후기인증니트][98project/1만장돌파] 톡톡 와플 반팔 니트 - 7 color ("민트그린,스카이블루" 프리오더)
# 브랜드 : 98도씨
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/GL3oIH0Ju2k/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzUwNjAxNzI0NTZmNWFlNTRmMzcwMTM3M2MwMDVlYTY3LmdpZg
# 카테고리 : 니트
# 판매가 : 32000
# 신상품 여부 : 0
# 리뷰 수 : 670
# 좋아요 수 : 22933
# 제품 사이즈 : FREE
# 제품명 : [한여름까지!여리여리] 살탐방지 빅사이즈 시스루 오버핏 브이넥 부클 스트릿 박시핏 니트
# 브랜드 : 블리즈
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/dkVDNCirrlk/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzL2I1MGY5MDNmMThhMzZkYzE1YjY2ZGY1ZTg2ZTg1NjE1LmdpZg
# 카테고리 : 니트
# 판매가 : 15500
# 신상품 여부 : 0
# 리뷰 수 : 8
# 좋아요 수 : 1290
# 제품 사이즈 : FREE
# 제품명 : [44-120] [2천장 돌파✨] 크리딘 스판 오픈카라 배색 니트
# 브랜드 : 리리앤코
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/Qu6BaJI2gRc/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzL2VhODllMjFhM2YzYjZkMmQ3YjJiNjg5Zjc2ZWE3Y2RmLmpwZw
# 카테고리 : 니트
# 판매가 : 26010
# 신상품 여부 : 0
# 리뷰 수 : 106
# 좋아요 수 : 4019
# 제품 사이즈 : FREE
# 제품명 : [썸머니트/루즈핏]슈링그물펀칭박스핏니트(4color)
# 브랜드 : 꼬맹
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/X6OLNFGtE8s/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzQzMzViMDFkNDI5YzliNTgwZThkNGZiYjQwZWUxOWU4LmdpZg
# 카테고리 : 니트
# 판매가 : 13900
# 신상품 여부 : 0
# 리뷰 수 : 3
# 좋아요 수 : 1552
# 제품 사이즈 : FREE
# 제품명 : [3500장 돌파/여름니트] unique hole knit (3color)
# 브랜드 : 바이마이미
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/JMBq7xa39qY/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzL2I5ZjA5MDNkNjQ0MjAzNDBhNGIyZTc3YmFkOGM5NGZhLmdpZg
# 카테고리 : 니트
# 판매가 : 18410
# 신상품 여부 : 0
# 리뷰 수 : 383
# 좋아요 수 : 19250
# 제품 사이즈 : FREE
# 제품명 : [🔥1+1추가할인🔥/갓성비] 최저가 재 진행! 여름 썸머 니트!~
# 브랜드 : 조이몰
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/W1jfYbLRK04/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzhiYmQ1OTI5ZjliOGMyNzI3ZDVkNmM5ODNmYTM5MzliLmdpZg
# 카테고리 : 니트
# 판매가 : 13800
# 신상품 여부 : 0
# 리뷰 수 : 6
# 좋아요 수 : 1234
# 제품 사이즈 : FREE
# 제품명 : [🏆니트1위/누적판매5만장] 오프닝 배색 니트 /여름니트/휴양지룩/바캉스/여름반팔니트/팔뚝살커버/여름하객룩
# 브랜드 : 체리코코
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/bVI5ELTGCdM/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzYzYTk1OGYzYWE1NDQ5YTYxZmNiZDBkMGRmYzVlYTJkLmdpZg
# 카테고리 : 니트
# 판매가 : 19900
# 신상품 여부 : 0
# 리뷰 수 : 396
# 좋아요 수 : 4433
# 제품 사이즈 : FREE
# 제품명 : [MADE/당일발송🎁] 샐러리 카라 반팔 니트 - 4color
# 브랜드 : 멜로우어썸
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/xlJbkFweFEg/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzExMWYyOWRjNmI1YmE3MjA2NDA4Mzk4NWIzZGE5NDhlLmdpZg
# 카테고리 : 니트
# 판매가 : 36540
# 신상품 여부 : 0
# 리뷰 수 : 72
# 좋아요 수 : 4968
# 제품 사이즈 : FREE
# 제품명 : [Mayvi/여름니트] ditu 린넨 반팔 니트 (3 color)
# 브랜드 : 언더비
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/tTEx3wQttf8/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzL2I0MjY2Y2NhNDk2NzM3N2EzZTBkZWFjNTdjNjYyZjY4LmdpZg
# 카테고리 : 니트
# 판매가 : 29450
# 신상품 여부 : 0
# 리뷰 수 : 16
# 좋아요 수 : 2512
# 제품 사이즈 : FREE
# 제품명 : [살안타템!/여리여리~] 손등덮는 루즈핏 부클 린넨 크롭 브이넥 긴팔 니트 (7color)
# 브랜드 : 베리버블
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/_KJ9iFt0qUs/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzZmMGQxODMzYjlhYmJhMmE1NTVkMWFkZTc0Njk1MDIxLmdpZg
# 카테고리 : 니트
# 판매가 : 15500
# 신상품 여부 : 0
# 리뷰 수 : 259
# 좋아요 수 : 10298
# 제품 사이즈 : FREE
# 제품명 : [15천장돌파][무려9컬러!] 둥글 스퀘어넥 반팔 니트 (9color)
# 브랜드 : 프리티띵즈
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/G2LxLgjnU0E/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzNjZTIxNTlkYjgzOGMwOTdhZmZhODgzYjMxMDAwZTA2LmdpZg
# 카테고리 : 니트
# 판매가 : 20500
# 신상품 여부 : 0
# 리뷰 수 : 3052
# 좋아요 수 : 41863
# 제품 사이즈 : FREE
# 제품명 : [오늘출발][3천장돌파/린넨니트/바캉스룩][자체제작] mnt607 쿨링 여리핏 유넥 린넨 니트
# 브랜드 : 에드모어
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/KwSbsUPWf30/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzL2JhZDJkN2E4MmI5YmMyYmEyYTRiZjY3ZTJlZWM5NGRmLmdpZg
# 카테고리 : 니트
# 판매가 : 31500
# 신상품 여부 : 0
# 리뷰 수 : 43
# 좋아요 수 : 1411
# 제품 사이즈 : FREE
# 제품명 : 배색자수니트-knit (아무거나 말고 예쁜룩😍)
# 브랜드 : 디스코살롱
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/5TIytMl4xQ0/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzYwYjJkNTg4OTcxYjY0ZjgyYzIyNDU2MjQ4NGRhNmEwLmdpZg
# 카테고리 : 니트
# 판매가 : 20000
# 신상품 여부 : 0
# 리뷰 수 : 42
# 좋아요 수 : 545
# 제품 사이즈 : FREE
# 제품명 : [주문폭주/예쁨주의] 인기 재진행 색상추가💕썸머 부클 반팔 니트 - nt
# 브랜드 : 우원
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/3woGbux7hMU/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzIwMjIwNTEyXzE2NTIzNjA1NDgwNjEzOTBzLmdpZg
# 카테고리 : 니트
# 판매가 : 16450
# 신상품 여부 : 0
# 리뷰 수 : 410
# 좋아요 수 : 9844
# 제품 사이즈 : FREE
# 제품명 : 당일발송｜[조절ok!/반팔ver.🤍] 오브 뱀부 트임 반팔 랩니트 티셔츠 - 5color
# 브랜드 : 슈가파우더
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/2kpPP0J11-0/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzL2QwN2FkOGVhN2FhNWVjYjZkMjRjNTE5ZTZiYjViZDQyLmdpZg
# 카테고리 : 니트
# 판매가 : 22700
# 신상품 여부 : 0
# 리뷰 수 : 108
# 좋아요 수 : 6577
# 제품 사이즈 : FREE
# 제품명 : 반팔ver.[일체형!/데일리힙]셔츠꽈배기니트레이어드반팔(5color)
# 브랜드 : 꼬맹
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/UNIcNe4hSMg/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzE4Y2M1ZjJiZDJmZjRjOTEzMjQwOTZhYmZlNGRlYjI1LmdpZg
# 카테고리 : 니트
# 판매가 : 14900
# 신상품 여부 : 0
# 리뷰 수 : 357
# 좋아요 수 : 17244
# 제품 사이즈 : FREE
# 제품명 : [44-120] [1만장 돌파♥] 르마턴 꽈배기 세미크롭 브이넥 반팔 니트
# 브랜드 : 리리앤코
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/-o6K32oNrRg/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzL2ZjNmQzNzAxNDllYTRlNDkzZmY5ZjRkNDU3ZTQzYjE4LmpwZw
# 카테고리 : 니트
# 판매가 : 24210
# 신상품 여부 : 0
# 리뷰 수 : 569
# 좋아요 수 : 10785
# 제품 사이즈 : FREE
# 제품명 : [🎁재진행] 골지 브이넥 카라 반팔 니트 - 6 color
# 브랜드 : 메이글
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/fmg4oRg88pw/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzL2IzZThmNTNjZjViNjNmZjNlNTNkMDMxZDI1NTgzNGYyLmdpZg
# 카테고리 : 니트
# 판매가 : 16240
# 신상품 여부 : 0
# 리뷰 수 : 7
# 좋아요 수 : 152
# 제품 사이즈 : FREE
# 제품명 : 🚚당일출고🚚[가벼운니트재질] 골지 카라넥 반팔 가디건
# 브랜드 : 리리의감각
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/5zLq7og9sb8/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzUyZTdjOTgyYTFkMTUxMzFkN2M1MmVjODM3NmU0YzBkLmdpZg
# 카테고리 : 가디건
# 판매가 : 14900
# 신상품 여부 : 0
# 리뷰 수 : 1811
# 좋아요 수 : 26476
# 제품 사이즈 : FREE
# 제품명 : [허리버튼!/색감맛집] 데일리, 부드러운 유넥 크롭 반팔니트 (9color)
# 브랜드 : 앤드모어
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/Fg2kSH5D1KM/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzg0MzJmZDdhNmIyNjY3NzNjYTM5NDRiZDU0MTRlOTlmLmdpZg
# 카테고리 : 니트
# 판매가 : 19500
# 신상품 여부 : 0
# 리뷰 수 : 183
# 좋아요 수 : 5804
# 제품 사이즈 : FREE
# 제품명 : [44-120] [1만4천장 돌파♥] 데니샤 스판 울 니트 세미크롭 오픈카라 브이넥 가디건
# 브랜드 : 리리앤코
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/VqMWhJSwyIw/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzL2YyYjA5ZWZmYWEzOTkxZDdhNjQ0YmRjOTUwN2E5NmE5LmpwZw
# 카테고리 : 니트
# 판매가 : 25110
# 신상품 여부 : 0
# 리뷰 수 : 543
# 좋아요 수 : 7758
# 제품 사이즈 : FREE
# 제품명 : *[기본템] FW 올리 브이넥 루즈핏 니트 티셔츠 6color [BKK-0393]
# 브랜드 : 모노치코
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/z1ytGtYr2kI/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzL2U3NjExY2U0Y2U3YzI1MWIzOGNlMDFmNmExZTZlYjlhLmpwZw
# 카테고리 : 니트
# 판매가 : 15800
# 신상품 여부 : 0
# 리뷰 수 : 142
# 좋아요 수 : 1848
# 제품 사이즈 : FREE
# 제품명 : 오션 케이블 루즈 썸머 보트넥 니트 (5color)
# 브랜드 : 쇼퍼랜드
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/8P9gZVZZoh8/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzAxNjFkZjI4MjQyMDZjMWRkNjJjMGE3NDA0MzYwYmQ2LmdpZg
# 카테고리 : 니트
# 판매가 : 16650
# 신상품 여부 : 0
# 리뷰 수 : 106
# 좋아요 수 : 4194
# 제품 사이즈 : FREE
# 제품명 : [44~100] 극여리핏 린넨 썸머 루즈핏 가디건
# 브랜드 : 쏠트베이비
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/P4ACozxJuBA/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzMwNmU2ZGY0YTFhOGY4NmY5MWRlZDlkNzVjNDcwYjJkLmdpZg
# 카테고리 : 가디건
# 판매가 : 17500
# 신상품 여부 : 0
# 리뷰 수 : 727
# 좋아요 수 : 10448
# 제품 사이즈 : FREE
# 제품명 : [데일리] 모던 카라 꽈배기 반팔 니트
# 브랜드 : 슬로우베리
# 이미지 url : https://d3ha2047wt6x28.cloudfront.net/38K7zRWIMGA/pr:NEW_GOODS_THUMB_STILL/czM6Ly9hYmx5LWltYWdlLWxlZ2FjeS9kYXRhL2dvb2RzLzIwMjIwNzEyXzE2NTc2MTgxNTE5MjI2ODJzLmdpZg
# 카테고리 : 니트
# 판매가 : 25500
# 신상품 여부 : 0
# 리뷰 수 : 2
# 좋아요 수 : 92
# 제품 사이즈 : FREE

# %%
def return_json_data(url) :

    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36',
            'X-Anonymous-Token' : 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhbm9ueW1vdXNfaWQiOiIyMzkyNzcyODgiLCJpYXQiOjE3MTgyMzkwMzd9.AXFzzsBNgrqEXyT-R_x7L-20MLdNUtMJb_W5A22hXWk'
            }

    res = requests.get(url, headers = headers)

    res.status_code

    return res.json(), res.status_code


def extract_goods_info(ably, status_code) :
    search_keyword = ably['logging']['analytics']['SEARCH_KEYWORD']
      
    filtered_components = [component['entity'] for component in ably['components'] if component['component_id'] == 41]
    
    good_name, market_name, image_url, category, good_num, price, is_new, review_count, likes_count, size, keyword, st_code = [[] for _ in range(12)]


    for entity in filtered_components :
        goods_data = entity['item_list']
        for good_data in goods_data :
            
            good_name.append(good_data['item']['name'])
            market_name.append(good_data['item']['market_name'])
            image_url.append(good_data['item']['image'])
            category.append(good_data['item']['category_name'])
            
            good_num.append( 'https://m.a-bly.com/goods/' + good_data['logging']['analytics']['GOODS_SNO'])
            price.append(good_data['logging']['analytics']['SALES_PRICE'])
            is_new.append(good_data['logging']['analytics']['IS_NEW'])
            review_count.append(good_data['logging']['analytics']['REVIEW_COUNT'])
            likes_count.append(good_data['logging']['analytics']['LIKES_COUNT'])

            size.append('FREE' if good_data['render']['size'] == 'MEDIUM' else good_data['render']['size'])

            keyword.append(search_keyword)

            st_code.append(status_code)
    
    if ably.get('next_token') :
        next_token = ably.get('next_token')
        return [good_name, market_name, image_url, category, good_num, price, is_new, review_count, likes_count, size, keyword, st_code, next_token]
    else :
        return [good_name, market_name, image_url, category, good_num, price, is_new, review_count, likes_count, size, keyword, st_code]

# %%
def ably_main_crawler(base_url, num_requests) :
    # 첫 번째 요청을 보낸다.
    base_url =  base_url
    ably, status_code = return_json_data(base_url)
    data = extract_goods_info(ably, status_code)

    # next_token
    next_token = data[-1]

    total_good_name, total_market_name, total_image_url, total_category, total_good_num ,total_price, total_is_new, total_review_count, total_likes_count, total_size, total_keyword, total_st_code = [[] for _ in range(12)]

    num_requests = 5
    count = 0
    while next_token and count <= num_requests:
        next_url = f'{base_url}&nextToken={next_token}'
        ably, status_code = return_json_data(next_url)
        data = extract_goods_info(ably, status_code)
        
        total_good_name.extend(data[0])
        total_market_name.extend(data[1])
        total_image_url.extend(data[2])
        total_category.extend(data[3])
        total_good_num.extend(data[4])
        total_price.extend(data[5])
        total_is_new.extend(data[6])
        total_review_count.extend(data[7])
        total_likes_count.extend(data[8])
        total_size.extend(data[9])
        total_keyword.extend(data[10])
        total_st_code.extend(data[11])
        
        # next_token이 없으면 일단 해당 반복 데이터는 넣고, 더 할 필요가 없으니까 종료(break)
        if len(data) == 12 :
            break
        # next_token이 있으면 해당 반복 데이터 넣어주고, next_token 재정의하기
        elif len(data) == 13 :
            next_token = data[-1]
        
        
    return total_good_name, total_market_name, total_image_url, total_category, total_good_num, total_price, total_is_new, total_review_count, total_likes_count, total_size, total_keyword, total_st_code

# %%
def make_ably_dataframe(datas) :

    data_composition = {
        'good_name' : datas[0], 
        'market_name' : datas[1],
        'image_url' : datas[2],
        'category' : datas[3],
        'connect_url' : datas[4],
        'price' : datas[5],
        'is_new' : datas[6],
        'review_count' : datas[7],
        'likes_count' : datas[8],
        'size' : datas[9],
        'keyword' : datas[10],
        'st_code' : datas[11]
    }

    return pd.DataFrame(data_composition)
# Out:
#                                             good_name market_name  \
# 0          [오늘출발🚚/여름슬랙스/기장선택/S~2XL] 코지 세미 와이드 핏 롱 슬랙스         모어핏
# 1   [🔥New특가🔥 1위여름슬랙스]💙썸머 투핀턱 와이드 슬랙스💙(11컬러,여름바지,와이...         고고싱
# 2                 [여름.VER] 아이브 쿨 정핏 더블 핀턱 와이드 일자핏 슬랙스          핏시
# 3   🎉7만장돌파🎉5컬러,썸머슬랙스 반하이 모찌슬랙스 ver.여름세미부츠컷 (바지팬츠,얇...         고고싱
# 4   *여름추가!*(S~2XL)(숏,미디,롱)*기장선택* 리얼 하이핏 투버튼 슬랙스 3C...         뮤즈핏
# 5   [8만장돌파!👍편안한속밴딩+슬림핏!] 중독슬랙스(속밴딩)ver.슬림와이드 (허리밴딩...         고고싱
# 6   ❤️15%쿠폰❤️ [❄️여름원단❄️S~2XL] 쿨 나일론 히든버튼 투핀턱 롱 썸머 ...        조이조이
# 7     *쫀쫀부츠컷*숏,롱/S~XL* YKK 히든버클+히든밴딩 와이드 부츠컷 슬랙스 3COL         뮤즈핏
# 8        ~2XL[기장선택/"찐인생슬랙스"]인생 가로버튼 안단추 핀턱 롱와이드 슬랙스팬츠       복플레이스
# 9   ❤️15%쿠폰❤️ ❣️15만장돌파❣️[숏,기본,롱/~2XL] 투데이 인생핏 와이드 ...        조이조이
# 10                 [#155~170#XS~2XL]에브리띵 와이드 롱 슬랙스 모음      1015마켓
# 11  *여름추가*(S~2XL)[숏,일반,롱] "슬랙스맛집" 기장수선NO! 투턱 와이드 슬...         뮤즈핏
# 12  [군살제로!/기장선택,2XL까지] 차르르~ 인생핏! 하이웨스트 투핀턱 와이드 롱슬랙...        앤드모어
# 13  여름슬랙스🌊[3가지기장/-2XL/히든밴딩] 리스 핀턱 와이드핏 롱 밴딩 슬랙스 1c...         모어핏
# 14    [핏존예/벨트set/여름슬랙스] 사트 하이웨스트 투핀턱 와이드 슬랙스 (5color)         더핑크
# 15  ❤️15%쿠폰❤️ [2기장/~2XL] 알렌 와이드핏 하프 슬랙스 여름 하이웨스트 핀...        조이조이
# 16              [3가지기장/2XL까지] 투버튼 세미 와이드핏 슬랙스 3colors         모어핏
# 17               *여름추가!* (3COL*뒷밴딩) 투버튼 하이웨스트 와이드 슬랙스         뮤즈핏
# 18          *여름버전추가*[핏보장] 썸띵 하이웨스트 투버튼 뒷밴딩 와이드 핀턱 슬랙스         모어핏
# 19              [찰랑썸머팬츠💦] [구김적은,인생핏슬랙스] 사이드지퍼 세미부츠컷SL         고고싱
# 20  썸머추가🌊[MADE/당일배송] 여름 일자핏 롱 레그 슬랙스 바지 3color/굿포유...          니썸
# 21                 [숏.기본.롱ver] 올리비아 더블 핀턱 와이드 일자핏 슬랙스          핏시
# 22    ~2XL[기장선택/"여름슬랙스"]린넨 느낌 핀턱 롱와이드 여름 출근룩 휴가 슬랙스팬츠       복플레이스
# 23  BEST바지👍 [ 2XL 빅사이즈⭕ / 하객룩💐 / 스판😍 ] 인밴딩 세미 부츠컷 ...       시크릿라벨
# 24       [컬러추가/~XL까지/3기장] #made 히든버클 핀턱 와이드슬랙스 7color         밀크티
# 25                    [텐셀나일론/한여름용슬랙스] 💦아이스 텐셀 투핀턱 팬츠💦         고고싱
# 26  썸머ver출시!누적20만장🏆[MADE] 어텐션 군살 커버 스트레이트핏 쫀쫀 슬랙스 ...          니썸
# 27  [누적1만장🔥] -5도 쿨링슬랙스✨오늘출발(일부)🚀#제작 [tsl0277][미슐랭 ...       어나더트위
# 28  [140cm~/S~2XL/봄신상/새학기/기모선택] 하이웨스트 부츠컷/일자핏 슬랙스 ...         제이닝
# 29  [S~3XL/편한바지💫] 히든밴딩와이드슬랙스 (3color) #빅사이즈#롱#체형커버...      그레이레이즈
# 30  <여름슬랙스/핏보장> 하이웨스트 투버튼 뒷밴딩 와이드 핀턱 슬랙스 [162이하키작녀...         더핑크
# 31           [🐳여름슬랙스BEST🐳][S~2XL/기장선택]수선놉67 썸머언더핀턱슬랙스        큐니걸스
# 32  ✨여름ver입고✨[140cm~/S-2XL/기장선택/당일/봄신상] 제이닝 리얼 하이핏...         제이닝
# 33          (기본&롱ver/뒷밴딩!) 썸머 시그니처 핀턱 세미부츠컷슬랙스 4color         밀크티
# 34          ~2XL[린넨st/기장선택] 쿨링 와이드 하이웨스트 여름 슬랙스(3col)        얼그레이
# 35         [18만장돌파!🙏일자와이드슬랙스1위/15컬러] 💖 탐나는 하이와이드 슬랙스💖         고고싱
#
#                                             image_url category  \
# 0   https://d3ha2047wt6x28.cloudfront.net/8MwRvLHy...      슬랙스
# 1   https://d3ha2047wt6x28.cloudfront.net/0rTwe5kc...      슬랙스
# 2   https://d3ha2047wt6x28.cloudfront.net/AVnCSrJl...      슬랙스
# 3   https://d3ha2047wt6x28.cloudfront.net/qHFsQBvk...      슬랙스
# 4   https://d3ha2047wt6x28.cloudfront.net/b9LlDEVQ...      슬랙스
# 5   https://d3ha2047wt6x28.cloudfront.net/KrK-4AjY...      슬랙스
# 6   https://d3ha2047wt6x28.cloudfront.net/TuwAkqYd...      슬랙스
# 7   https://d3ha2047wt6x28.cloudfront.net/n2G31UPx...      슬랙스
# 8   https://d3ha2047wt6x28.cloudfront.net/Ov3K2QXN...      슬랙스
# 9   https://d3ha2047wt6x28.cloudfront.net/mRooR9vp...      슬랙스
# 10  https://d3ha2047wt6x28.cloudfront.net/J3EqNex0...      슬랙스
# 11  https://d3ha2047wt6x28.cloudfront.net/Xnh-HwxJ...      슬랙스
# 12  https://d3ha2047wt6x28.cloudfront.net/3wrTb1yt...      슬랙스
# 13  https://d3ha2047wt6x28.cloudfront.net/tO2vJzDZ...      슬랙스
# 14  https://d3ha2047wt6x28.cloudfront.net/pjTWmYei...      슬랙스
# 15  https://d3ha2047wt6x28.cloudfront.net/BkZ5ZLTD...      슬랙스
# 16  https://d3ha2047wt6x28.cloudfront.net/ejihxo5L...      슬랙스
# 17  https://d3ha2047wt6x28.cloudfront.net/RvdM6Fkj...      슬랙스
# 18  https://d3ha2047wt6x28.cloudfront.net/C6qhgYh1...      슬랙스
# 19  https://d3ha2047wt6x28.cloudfront.net/8t6YbtAO...      슬랙스
# 20  https://d3ha2047wt6x28.cloudfront.net/dluZt3pd...      슬랙스
# 21  https://d3ha2047wt6x28.cloudfront.net/K3-3e8OH...      슬랙스
# 22  https://d3ha2047wt6x28.cloudfront.net/WCV4Ozdm...      슬랙스
# 23  https://d3ha2047wt6x28.cloudfront.net/UEBhwfMv...      슬랙스
# 24  https://d3ha2047wt6x28.cloudfront.net/OT-U2Tt-...      슬랙스
# 25  https://d3ha2047wt6x28.cloudfront.net/BliEX0Ak...      슬랙스
# 26  https://d3ha2047wt6x28.cloudfront.net/f3RGz5e5...      슬랙스
# 27  https://d3ha2047wt6x28.cloudfront.net/t8UmLz__...      슬랙스
# 28  https://d3ha2047wt6x28.cloudfront.net/MjVURWDy...      슬랙스
# 29  https://d3ha2047wt6x28.cloudfront.net/g--1VTva...      슬랙스
# 30  https://d3ha2047wt6x28.cloudfront.net/yz54ALjp...      슬랙스
# 31  https://d3ha2047wt6x28.cloudfront.net/Ln-3nv0_...      슬랙스
# 32  https://d3ha2047wt6x28.cloudfront.net/nSaYEGH5...      슬랙스
# 33  https://d3ha2047wt6x28.cloudfront.net/wHK6NZLC...      슬랙스
# 34  https://d3ha2047wt6x28.cloudfront.net/cX9Ci45P...      슬랙스
# 35  https://d3ha2047wt6x28.cloudfront.net/-yXM6gut...      슬랙스
#
#                            connect_url  price is_new  review_count  \
# 0    https://m.a-bly.com/goods/4537232  19060      0          9829
# 1    https://m.a-bly.com/goods/7147760  29800      0          1562
# 2   https://m.a-bly.com/goods/20822602  22500      0             0
# 3    https://m.a-bly.com/goods/2907820  29800      0          2201
# 4    https://m.a-bly.com/goods/5579667  17570      0         11643
# 5    https://m.a-bly.com/goods/2917785  22900      0          4770
# 6    https://m.a-bly.com/goods/7207165  19850      0          1163
# 7   https://m.a-bly.com/goods/16071383  15960      0           878
# 8    https://m.a-bly.com/goods/5711054  23500      0          2208
# 9    https://m.a-bly.com/goods/4202364  20800      0         32028
# 10   https://m.a-bly.com/goods/2077167  17910      0         30511
# 11   https://m.a-bly.com/goods/6488274  19900      0          1218
# 12   https://m.a-bly.com/goods/6242451  23500      0          1924
# 13  https://m.a-bly.com/goods/16986159  19340      0           158
# 14  https://m.a-bly.com/goods/17846420  18130      0           357
# 15  https://m.a-bly.com/goods/18168834  18900      0           263
# 16   https://m.a-bly.com/goods/3474049  18130      0         16230
# 17   https://m.a-bly.com/goods/4018653  17570      0          1296
# 18   https://m.a-bly.com/goods/4090607  18130      0          4799
# 19   https://m.a-bly.com/goods/4275158  20860      0           459
# 20   https://m.a-bly.com/goods/2776040  19420      0          3783
# 21   https://m.a-bly.com/goods/6080857  23500      0          8832
# 22   https://m.a-bly.com/goods/7103591  20500      0           343
# 23   https://m.a-bly.com/goods/2660954  31000      0           498
# 24   https://m.a-bly.com/goods/4589375  17950      0         11475
# 25  https://m.a-bly.com/goods/20297866  33060      0             6
# 26   https://m.a-bly.com/goods/5558289  26770      0          2263
# 27   https://m.a-bly.com/goods/7926214  27840      0            44
# 28   https://m.a-bly.com/goods/3514696  17950      0          8927
# 29  https://m.a-bly.com/goods/15683105  17910      0            73
# 30   https://m.a-bly.com/goods/2394451  18410      0         36931
# 31   https://m.a-bly.com/goods/4167882  25010      0           178
# 32   https://m.a-bly.com/goods/5849502  17950      0          1952
# 33   https://m.a-bly.com/goods/4166919  17950      0           292
# 34   https://m.a-bly.com/goods/8175929  20500      0            44
# 35   https://m.a-bly.com/goods/2917865  28960      0          4398
#
#     likes_count  size keyword  st_code
# 0         69493  FREE     슬랙스      200
# 1         33255  FREE     슬랙스      200
# 2           155  FREE     슬랙스      200
# 3         18062  FREE     슬랙스      200
# 4        100657  FREE     슬랙스      200
# 5         37602  FREE     슬랙스      200
# 6         15774  FREE     슬랙스      200
# 7         11990  FREE     슬랙스      200
# 8         22513  FREE     슬랙스      200
# 9        206657  FREE     슬랙스      200
# 10       150483  FREE     슬랙스      200
# 11        13264  FREE     슬랙스      200
# 12        19466  FREE     슬랙스      200
# 13         5123  FREE     슬랙스      200
# 14        15426  FREE     슬랙스      200
# 15         6123  FREE     슬랙스      200
# 16        89544  FREE     슬랙스      200
# 17        12999  FREE     슬랙스      200
# 18        40922  FREE     슬랙스      200
# 19         9467  FREE     슬랙스      200
# 20        22224  FREE     슬랙스      200
# 21        77107  FREE     슬랙스      200
# 22         2716  FREE     슬랙스      200
# 23        11106  FREE     슬랙스      200
# 24        70795  FREE     슬랙스      200
# 25          269  FREE     슬랙스      200
# 26        12607  FREE     슬랙스      200
# 27         1843  FREE     슬랙스      200
# 28        42017  FREE     슬랙스      200
# 29         1298  FREE     슬랙스      200
# 30       198769  FREE     슬랙스      200
# 31         6045  FREE     슬랙스      200
# 32        11480  FREE     슬랙스      200
# 33         4263  FREE     슬랙스      200
# 34          585  FREE     슬랙스      200
# 35        41253  FREE     슬랙스      200
